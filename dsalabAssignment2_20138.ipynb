# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h3> Answer 1 </h3>

# %% [markdown]
# <p> <b> (1) </b> </p>

# %%
df=pd.read_csv("Question1.csv")

# %%
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0      0    0        3944153            3944160          3951330
# 1      0    1        3978070            3978090          3957888
# 2      0    2        4096929            4096939          4090862
# 3      0    3        4119040            4119051          4111920
# 4      0    4        4063170            4063186          4077551
# ..   ...  ...            ...                ...              ...
# 301    2   97          53582              53605            54118
# 302    2   98          36641              36675            37532
# 303    2   99          26193              26214            26074
# 304    2  100          44202              44246            45058
# 305    2  999      156964212          156969328        157258820
#
#      POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0            3963087          3926540          3931141          3949775
# ...

# %% [markdown]
# <p> <b> (2) </b> </p>

# %%
print("SIZE : ",df.size)
print("SHAPE : ",df.shape)
# Out:
# SIZE :  3060
# SHAPE :  (306, 10)

# %% [markdown]
# <p> <b> (3) </b> </p>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0      0    0        3944153            3944160          3951330
# 1      0    1        3978070            3978090          3957888
# 2      0    2        4096929            4096939          4090862
# 3      0    3        4119040            4119051          4111920
# 4      0    4        4063170            4063186          4077551
# ..   ...  ...            ...                ...              ...
# 301    2   97          53582              53605            54118
# 302    2   98          36641              36675            37532
# 303    2   99          26193              26214            26074
# 304    2  100          44202              44246            45058
# 305    2  999      156964212          156969328        157258820
#
#      POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0            3963087          3926540          3931141          3949775
# ...

# %% [markdown]
# <p> <b> (4) </b> </p>

# %%
df=df.rename(columns={"POPESTIMATE2010":"2010","POPESTIMATE2014":"2014"})
df
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160    3951330          3963087
# 1      0    1        3978070            3978090    3957888          3966551
# 2      0    2        4096929            4096939    4090862          3971565
# 3      0    3        4119040            4119051    4111920          4102470
# 4      0    4        4063170            4063186    4077551          4122294
# ..   ...  ...            ...                ...        ...              ...
# 301    2   97          53582              53605      54118            57159
# 302    2   98          36641              36675      37532            40116
# 303    2   99          26193              26214      26074            27030
# 304    2  100          44202              44246      45058            47556
# 305    2  999      156964212          156969328  157258820        158427085
#
# ...

# %% [markdown]
# <p> <b> (5) </b> </p>

# %%
df.head(10)
# Out:
#    SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0    0    0        3944153            3944160  3951330          3963087
# 1    0    1        3978070            3978090  3957888          3966551
# 2    0    2        4096929            4096939  4090862          3971565
# 3    0    3        4119040            4119051  4111920          4102470
# 4    0    4        4063170            4063186  4077551          4122294
# 5    0    5        4056858            4056872  4064653          4087709
# 6    0    6        4066381            4066412  4073013          4074993
# 7    0    7        4030579            4030594  4043046          4083225
# 8    0    8        4046486            4046497  4025604          4053203
# 9    0    9        4148353            4148369  4125415          4035710
#
#    POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0          3926540          3931141  3949775          3978038
# ...

# %% [markdown]
# <p> <b> (6) </b> </p>

# %%
selected_rows=df.loc[[15,22]]
selected_rows
# Out:
#     SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 15    0   15        4242820            4242946  4231002          4158941
# 22    0   22        4264642            4264946  4287005          4415300
#
#     POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 15          4144019          4149121  4164796          4249742
# 22          4628459          4665965  4615729          4529472

# %% [markdown]
# <p> <b> (7) </b> </p>

# %%
df_new=df[["SEX","AGE","2010","2014"]]

# %%
df_new
# Out:
#      SEX  AGE       2010       2014
# 0      0    0    3951330    3949775
# 1      0    1    3957888    3949776
# 2      0    2    4090862    3959664
# 3      0    3    4111920    4007079
# 4      0    4    4077551    4005716
# ..   ...  ...        ...        ...
# 301    2   97      54118      62779
# 302    2   98      37532      46208
# 303    2   99      26074      32517
# 304    2  100      45058      58008
# 305    2  999  157258820  161952064
#
# [306 rows x 4 columns]

# %%
df_new["Change"]=abs(df["2010"]-df["2014"])
df_new["Change_Percentage"]=(df_new["Change"]/df_new["2010"])*100
df_new
# Out:
# <ipython-input-11-d2a3819acbf8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["Change"]=abs(df["2010"]-df["2014"])
# <ipython-input-11-d2a3819acbf8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["Change_Percentage"]=(df_new["Change"]/df_new["2010"])*100
#      SEX  AGE       2010       2014   Change  Change_Percentage
# 0      0    0    3951330    3949775     1555           0.039354
# 1      0    1    3957888    3949776     8112           0.204958
# ...

# %% [markdown]
# <p> <b> (8) </b> </p>

# %%
graying_aspect=df_new[(df_new["AGE"]>=67) & (df_new["AGE"]<=71)]
graying_aspect
# Out:
#      SEX  AGE     2010     2014  Change  Change_Percentage
# 67     0   67  2693707  3485241  791534          29.384562
# 68     0   68  2359816  2572359  212543           9.006762
# 69     0   69  2167830  2534295  366465          16.904693
# 70     0   70  2062577  2465438  402861          19.531925
# 71     0   71  1953607  2519705  566098          28.977067
# 169    1   67  1270145  1652998  382853          30.142464
# 170    1   68  1105699  1211278  105579           9.548620
# 171    1   69  1006782  1186872  180090          17.887686
# 172    1   70   954073  1148508  194435          20.379468
# 173    1   71   903258  1169115  265857          29.433119
# 271    2   67  1423562  1832243  408681          28.708339
# 272    2   68  1254117  1361081  106964           8.529029
# 273    2   69  1161048  1347423  186375          16.052308
# 274    2   70  1108504  1316930  208426          18.802458
# 275    2   71  1050349  1350590  300241          28.584880

# %% [markdown]
# <p> <b> (9) </b> </p>

# %%
sample=df[df["AGE"]==0]
sample
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 102    1    0        2014276            2014278  2018420          2028427
# 204    2    0        1929877            1929882  1932910          1934660
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0            3926540          3931141  3949775          3978038
# 102          2007717          2009528  2020326          2035134
# 204          1918823          1921613  1929449          1942904

# %%
count1=sample["POPESTIMATE2015"].values[0]
count2=sample["POPESTIMATE2015"].values[1]
print("Boys - Girls ratio among infants =",count1/count2)
# Out:
# Boys - Girls ratio among infants = 1.954681116820809

# %% [markdown]
# <p> <b> (10) </b> </p>

# %%
male=df[df["SEX"]==0]
female=df[df["SEX"]==1]

# %%
female
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 102    1    0        2014276            2014278    2018420          2028427
# 103    1    1        2030853            2030861    2020332          2025522
# 104    1    2        2092198            2092202    2088685          2026973
# 105    1    3        2104550            2104555    2101272          2094296
# 106    1    4        2077550            2077556    2084312          2106323
# ..   ...  ...            ...                ...        ...              ...
# 199    1   97          14556              14563      14775            16115
# 200    1   98           9259               9263       9505            10554
# 201    1   99           6073               6075       6104             6606
# 202    1  100           9162               9166       9352            10146
# 203    1  999      151781326          151788777  152088043        153291772
#
# ...

# %%
dict={}
dict.update({"2010":(male["2010"].loc[101])/(female["2010"].loc[203])})
dict.update({"2011":(male["POPESTIMATE2011"].loc[101])/(female["POPESTIMATE2011"].loc[203])})
dict.update({"2012":(male["POPESTIMATE2012"].loc[101])/(female["POPESTIMATE2012"].loc[203])})
dict.update({"2013":(male["POPESTIMATE2013"].loc[101])/(female["POPESTIMATE2013"].loc[203])})
dict.update({"2014":(male["2014"].loc[101])/(female["2014"].loc[203])})
dict.update({"2015":(male["POPESTIMATE2015"].loc[101])/(female["POPESTIMATE2013"].loc[203])})
dict
# Out:
# {'2010': 2.0339985767322943,
#  '2011': 2.0335002520552767,
#  '2012': 2.032749376966872,
#  '2013': 2.032200623004382,
#  '2014': 2.031835343069602,
#  '2015': 2.0642571931843428}

# %%
print("The ratio is between 2 and 4 in all of these years")
# Out:
# The ratio is between 2 and 4 in all of these years

# %% [markdown]
# <p> <b> (11) </b> </p>

# %%
sample=df[(df["SEX"]==0) | (df["SEX"]==1)]
sample
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160    3951330          3963087
# 1      0    1        3978070            3978090    3957888          3966551
# 2      0    2        4096929            4096939    4090862          3971565
# 3      0    3        4119040            4119051    4111920          4102470
# 4      0    4        4063170            4063186    4077551          4122294
# ..   ...  ...            ...                ...        ...              ...
# 199    1   97          14556              14563      14775            16115
# 200    1   98           9259               9263       9505            10554
# 201    1   99           6073               6075       6104             6606
# 202    1  100           9162               9166       9352            10146
# 203    1  999      151781326          151788777  152088043        153291772
#
# ...

# %%
new_sample=sample.sort_values("AGE")
new_sample
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160    3951330          3963087
# 102    1    0        2014276            2014278    2018420          2028427
# 1      0    1        3978070            3978090    3957888          3966551
# 103    1    1        2030853            2030861    2020332          2025522
# 2      0    2        4096929            4096939    4090862          3971565
# ..   ...  ...            ...                ...        ...              ...
# 99     0   99          32266              32289      32178            33636
# 202    1  100           9162               9166       9352            10146
# 100    0  100          53364              53412      54410            57702
# 101    0  999      308745538          308758105  309346863        311718857
# 203    1  999      151781326          151788777  152088043        153291772
#
# ...

# %%
new_sample=new_sample[:202]
new_sample
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 102    1    0        2014276            2014278  2018420          2028427
# 1      0    1        3978070            3978090  3957888          3966551
# 103    1    1        2030853            2030861  2020332          2025522
# 2      0    2        4096929            4096939  4090862          3971565
# ..   ...  ...            ...                ...      ...              ...
# 98     0   98          45900              45938    47037            50670
# 201    1   99           6073               6075     6104             6606
# 99     0   99          32266              32289    32178            33636
# 202    1  100           9162               9166     9352            10146
# 100    0  100          53364              53412    54410            57702
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# ...

# %%
new_sample1=new_sample[new_sample["SEX"]==0]
new_sample1
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160  3951330          3963087
# 1      0    1        3978070            3978090  3957888          3966551
# 2      0    2        4096929            4096939  4090862          3971565
# 3      0    3        4119040            4119051  4111920          4102470
# 4      0    4        4063170            4063186  4077551          4122294
# ..   ...  ...            ...                ...      ...              ...
# 96     0   96          95223              95288    97161           101261
# 97     0   97          68138              68168    68893            73274
# 98     0   98          45900              45938    47037            50670
# 99     0   99          32266              32289    32178            33636
# 100    0  100          53364              53412    54410            57702
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# ...

# %%
new_sample2=new_sample[new_sample["SEX"]==1]
new_sample2
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 102    1    0        2014276            2014278  2018420          2028427
# 103    1    1        2030853            2030861  2020332          2025522
# 104    1    2        2092198            2092202  2088685          2026973
# 105    1    3        2104550            2104555  2101272          2094296
# 106    1    4        2077550            2077556  2084312          2106323
# ..   ...  ...            ...                ...      ...              ...
# 198    1   96          21424              21432    22022            23801
# 199    1   97          14556              14563    14775            16115
# 200    1   98           9259               9263     9505            10554
# 201    1   99           6073               6075     6104             6606
# 202    1  100           9162               9166     9352            10146
#
#      POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# ...

# %%
final_sample=new_sample1.div(new_sample2.values)

# %%
final_sample
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010      2010  POPESTIMATE2011  \
# 0    0.0  NaN       1.958100           1.958101  1.957635         1.953774
# 1    0.0  1.0       1.958817           1.958819  1.959029         1.958286
# 2    0.0  1.0       1.958194           1.958195  1.958583         1.959358
# 3    0.0  1.0       1.957207           1.957208  1.956872         1.958878
# 4    0.0  1.0       1.955751           1.955753  1.956305         1.957104
# ..   ...  ...            ...                ...       ...              ...
# 96   0.0  1.0       4.444688           4.446062  4.411997         4.254485
# 97   0.0  1.0       4.681094           4.680904  4.662809         4.546944
# 98   0.0  1.0       4.957339           4.959300  4.948659         4.801023
# 99   0.0  1.0       5.313025           5.315062  5.271625         5.091735
# 100  0.0  1.0       5.824492           5.827187  5.818007         5.687167
#
#      POPESTIMATE2012  POPESTIMATE2013      2014  POPESTIMATE2015
# ...

# %%
final_sample["INDEX"]=final_sample.index

# %%
final_sample=final_sample.drop(columns=["CENSUS2010POP","ESTIMATESBASE2010"])

# %%
final_sample=final_sample.rename(columns={"POPESTIMATE2011":"2011","POPESTIMATE2012":"2012","POPESTIMATE2013":"2013","POPESTIMATE2015":"2015"})

# %%
final_sample.plot(x="INDEX", y=["2014"], kind="bar",figsize=(50,50))
# Out:
# <AxesSubplot:xlabel='INDEX'>

# %% [markdown]
# <h></h>

# %% [markdown]
# <h></h>

# %% [markdown]
# <h></h>

# %% [markdown]
# <h3> Answer 2 </h3>

# %%
df=pd.read_csv("question2.csv")

# %% [markdown]
# <p> <b> (1) </b> </p>

# %%
df
# Out:
#               PLAYER POSITION                TEAM     SALARY
# 0       Paul Millsap       PF       Atlanta Hawks  18.671659
# 1         Al Horford        C       Atlanta Hawks  12.000000
# 2     Tiago Splitter        C       Atlanta Hawks   9.756250
# 3        Jeff Teague       PG       Atlanta Hawks   8.000000
# 4        Kyle Korver       SG       Atlanta Hawks   5.746479
# ..               ...      ...                 ...        ...
# 412        Gary Neal       PG  Washington Wizards   2.139000
# 413     DeJuan Blair        C  Washington Wizards   2.000000
# 414  Kelly Oubre Jr.       SF  Washington Wizards   1.920240
# 415   Garrett Temple       SG  Washington Wizards   1.100602
# 416     Jarell Eddie       SG  Washington Wizards   0.561716
#
# [417 rows x 4 columns]

# %% [markdown]
# <p> <b> (2) </b> </p>

# %%
print("SIZE : ",df.size)
print("SHAPE : ",df.shape)
# Out:
# SIZE :  1668
# SHAPE :  (417, 4)

# %% [markdown]
# <p> <b> (3) </b> </p>

# %%
df=df.sort_values("PLAYER")

# %%
df
# Out:
#               PLAYER POSITION                    TEAM     SALARY
# 68      Aaron Brooks       PG           Chicago Bulls   2.250000
# 291     Aaron Gordon       PF           Orlando Magic   4.171680
# 59    Aaron Harrison       SG       Charlotte Hornets   0.525093
# 235    Adreian Payne       PF  Minnesota Timberwolves   1.938840
# 1         Al Horford        C           Atlanta Hawks  12.000000
# ..               ...      ...                     ...        ...
# 95   Wilson Chandler       SF          Denver Nuggets  10.449438
# 233      Zach LaVine       PG  Minnesota Timberwolves   2.148360
# 181    Zach Randolph       PF       Memphis Grizzlies   9.638555
# 86     Zaza Pachulia        C        Dallas Mavericks   5.200000
# 26      Zoran Dragic       SG          Boston Celtics   1.706225
#
# [417 rows x 4 columns]

# %% [markdown]
# <p> <b> (4) </b> </p>

# %%
df_asc=df.sort_values("SALARY")
df_dsc=df.sort_values("SALARY",ascending=False)

# %% [markdown]
# <p> <b> (5) </b> </p>

# %%
df=df.rename(columns={"SALARY":"SALARY:"})
df
# Out:
#               PLAYER POSITION                    TEAM    SALARY:
# 68      Aaron Brooks       PG           Chicago Bulls   2.250000
# 291     Aaron Gordon       PF           Orlando Magic   4.171680
# 59    Aaron Harrison       SG       Charlotte Hornets   0.525093
# 235    Adreian Payne       PF  Minnesota Timberwolves   1.938840
# 1         Al Horford        C           Atlanta Hawks  12.000000
# ..               ...      ...                     ...        ...
# 95   Wilson Chandler       SF          Denver Nuggets  10.449438
# 233      Zach LaVine       PG  Minnesota Timberwolves   2.148360
# 181    Zach Randolph       PF       Memphis Grizzlies   9.638555
# 86     Zaza Pachulia        C        Dallas Mavericks   5.200000
# 26      Zoran Dragic       SG          Boston Celtics   1.706225
#
# [417 rows x 4 columns]

# %% [markdown]
# <p> <b> (6) </b> </p>

# %%
df.head(5)
# Out:
#              PLAYER POSITION                    TEAM    SALARY:
# 68     Aaron Brooks       PG           Chicago Bulls   2.250000
# 291    Aaron Gordon       PF           Orlando Magic   4.171680
# 59   Aaron Harrison       SG       Charlotte Hornets   0.525093
# 235   Adreian Payne       PF  Minnesota Timberwolves   1.938840
# 1        Al Horford        C           Atlanta Hawks  12.000000

# %% [markdown]
# <p> <b> (7) </b> </p>

# %%
display=df.loc[[3,10,22]]
display
# Out:
#             PLAYER POSITION            TEAM  SALARY:
# 3      Jeff Teague       PG   Atlanta Hawks  8.00000
# 10  Walter Tavares        C   Atlanta Hawks  1.00000
# 22    Kelly Olynyk        C  Boston Celtics  2.16516

# %% [markdown]
# <p> <b> (8) </b> </p>

# %%
df_dsc.head()
# Out:
#               PLAYER POSITION                 TEAM     SALARY
# 169      Kobe Bryant       SF   Los Angeles Lakers  25.000000
# 29       Joe Johnson       SF        Brooklyn Nets  24.894863
# 72      LeBron James       SF  Cleveland Cavaliers  22.970500
# 255  Carmelo Anthony       SF      New York Knicks  22.875000
# 131    Dwight Howard        C      Houston Rockets  22.359364

# %% [markdown]
# <p> <b> (9) </b> </p>

# %%
req=df[df["SALARY:"]>10].sort_values("SALARY:")
req
# Out:
#               PLAYER POSITION                 TEAM    SALARY:
# 368    DeMar DeRozan       SG      Toronto Raptors  10.050000
# 298   Gerald Wallace       SF   Philadelphia 76ers  10.105855
# 204        Luol Deng       SF           Miami Heat  10.151612
# 144      Monta Ellis       SG       Indiana Pacers  10.300000
# 95   Wilson Chandler       SF       Denver Nuggets  10.449438
# ..               ...      ...                  ...        ...
# 131    Dwight Howard        C      Houston Rockets  22.359364
# 255  Carmelo Anthony       SF      New York Knicks  22.875000
# 72      LeBron James       SF  Cleveland Cavaliers  22.970500
# 29       Joe Johnson       SF        Brooklyn Nets  24.894863
# 169      Kobe Bryant       SF   Los Angeles Lakers  25.000000
#
# [69 rows x 4 columns]

# %% [markdown]
# <p> <b> (10) </b> </p>

# %%
req=df[df["PLAYER"]=="Stephen Curry"]

# %%
req
# Out:
#             PLAYER POSITION                   TEAM    SALARY:
# 121  Stephen Curry       PG  Golden State Warriors  11.370786

# %% [markdown]
# <p> <b> (11) </b> </p>

# %%
req=df[(df["POSITION"]=="PG") & (df["SALARY:"]>15)]

# %%
req
# Out:
#                 PLAYER POSITION                   TEAM    SALARY:
# 156         Chris Paul       PG   Los Angeles Clippers  21.468695
# 60        Derrick Rose       PG          Chicago Bulls  20.093064
# 400          John Wall       PG     Washington Wizards  15.851950
# 74        Kyrie Irving       PG    Cleveland Cavaliers  16.407501
# 269  Russell Westbrook       PG  Oklahoma City Thunder  16.744218

# %% [markdown]
# <p> <b> (12) </b> </p>

# %%
df[df["TEAM"]=="Golden State Warriors"]
# Out:
#                 PLAYER POSITION                   TEAM    SALARY:
# 130   Anderson Varejao       PF  Golden State Warriors   0.289755
# 120     Andre Iguodala       SF  Golden State Warriors  11.710456
# 119       Andrew Bogut        C  Golden State Warriors  13.800000
# 128       Brandon Rush       SF  Golden State Warriors   1.270964
# 118     Draymond Green       PF  Golden State Warriors  14.260870
# 127       Festus Ezeli        C  Golden State Warriors   2.008748
# 124    Harrison Barnes       SF  Golden State Warriors   3.873398
# 122     Jason Thompson       PF  Golden State Warriors   7.008475
# 129       Kevon Looney       SF  Golden State Warriors   1.131960
# 117      Klay Thompson       SG  Golden State Warriors  15.501000
# 126    Leandro Barbosa       SG  Golden State Warriors   2.500000
# 125  Marreese Speights        C  Golden State Warriors   3.815000
# 123   Shaun Livingston       PG  Golden State Warriors   5.543725
# ...

# %% [markdown]
# <p> <b> (13) </b> </p>

# %%
req=df.groupby("TEAM").sum("SALARY:")

# %%
req
# Out:
#                            SALARY:
# TEAM
# Atlanta Hawks            69.573103
# Boston Celtics           50.285499
# Brooklyn Nets            57.306976
# Charlotte Hornets        84.102397
# Chicago Bulls            78.820890
# Cleveland Cavaliers     102.312412
# Dallas Mavericks         65.762559
# Denver Nuggets           62.429404
# Detroit Pistons          42.211760
# Golden State Warriors    94.085137
# Houston Rockets          85.285837
# Indiana Pacers           62.695023
# Los Angeles Clippers     66.074113
# Los Angeles Lakers       68.607944
# Memphis Grizzlies        93.796439
# Miami Heat               81.528667
# Milwaukee Bucks          52.258355
# Minnesota Timberwolves   65.847421
# New Orleans Pelicans     80.514606
# New York Knicks          69.404994
# Oklahoma City Thunder    96.832165
# Orlando Magic            77.623940
# Philadelphia 76ers       42.481345
# Phoenix Suns             50.520815
# Portland Trail Blazers   45.446878
# ...

# %% [markdown]
# <p> <b> (14) </b> </p>

# %%
req=df.groupby("POSITION").count()
req=req["PLAYER"]
req
# Out:
# POSITION
# C     69
# PF    85
# PG    85
# SF    82
# SG    96
# Name: PLAYER, dtype: int64

# %% [markdown]
# <p> <b> (15) </b> </p>

# %%
req=df.groupby("POSITION").mean("SALARY: ")
req
# Out:
#            SALARY:
# POSITION
# C         6.082913
# PF        4.951344
# PG        5.165487
# SF        5.532675
# SG        3.988195

# %% [markdown]
# <p></p>

# %% [markdown]
# <p> </p>

# %% [markdown]
# <p>  </p>

# %% [markdown]
# <h3> Answer 3 </h3>

# %%
df=pd.read_csv("Question3.csv")

# %%
df
# Out:
#              Year        Age  Gender          Educational Attainment  \
# 0     1/1/08 0:00   00 to 17    Male  College, less than 4-yr degree
# 1     1/1/08 0:00   00 to 17  Female  College, less than 4-yr degree
# 2     1/1/08 0:00  65 to 80+    Male  College, less than 4-yr degree
# 3     1/1/08 0:00  65 to 80+  Female          No high school diploma
# 4     1/1/08 0:00   00 to 17  Female          No high school diploma
# ...           ...        ...     ...                             ...
# 1021  1/1/14 0:00   18 to 64  Female       High school or equivalent
# 1022  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
# 1023  1/1/14 0:00   18 to 64  Female          No high school diploma
# 1024  1/1/14 0:00   18 to 64  Female     Bachelor's degree or higher
# 1025  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 0     C: 10,000 to 14,999              1304
# 1       B: 5,000 to 9,999              1565
# ...

# %%
df["Age"].unique()
# Out:
# array(['00 to 17', '65 to 80+', '18 to 64'], dtype=object)

# %%
df["Year"].unique()
# Out:
# array(['1/1/08 0:00', '1/1/09 0:00', '1/1/10 0:00', '1/1/11 0:00',
#        '1/1/12 0:00', '1/1/13 0:00', '1/1/14 0:00'], dtype=object)

# %%
df=df[(((df["Age"]=="18 to 64") | (df["Age"]=="65 to 80+")) & (df['Year']=="1/1/14 0:00"))]

# %%
df
# Out:
#              Year        Age  Gender       Educational Attainment  \
# 885   1/1/14 0:00   18 to 64  Female       No high school diploma
# 886   1/1/14 0:00  65 to 80+    Male       No high school diploma
# 894   1/1/14 0:00  65 to 80+  Female       No high school diploma
# 895   1/1/14 0:00  65 to 80+  Female    High school or equivalent
# 896   1/1/14 0:00  65 to 80+  Female       No high school diploma
# ...           ...        ...     ...                          ...
# 1021  1/1/14 0:00   18 to 64  Female    High school or equivalent
# 1022  1/1/14 0:00   18 to 64    Male  Bachelor's degree or higher
# 1023  1/1/14 0:00   18 to 64  Female       No high school diploma
# 1024  1/1/14 0:00   18 to 64  Female  Bachelor's degree or higher
# 1025  1/1/14 0:00   18 to 64    Male  Bachelor's degree or higher
#
#           Personal Income  Population Count
# 885    H: 75,000 and over              2058
# 886    H: 75,000 and over              2153
# ...

# %% [markdown]
# <p> <b> (1) </b> </p>

# %%
req=df.groupby("Educational Attainment").sum("Population Count")
req
# Out:
#                                 Population Count
# Educational Attainment
# Bachelor's degree or higher              8525698
# College, less than 4-yr degree           7775497
# High school or equivalent                6294141
# No high school diploma                   4258277

# %% [markdown]
# <p> <b> (2) </b> </p>

# %%
req["Percentage"]=(req["Population Count"]/req["Population Count"].sum())*100

# %%
req
# Out:
#                                 Population Count  Percentage
# Educational Attainment
# Bachelor's degree or higher              8525698   31.748793
# College, less than 4-yr degree           7775497   28.955124
# High school or equivalent                6294141   23.438712
# No high school diploma                   4258277   15.857371

# %% [markdown]
# <p> <b> (3) </b> </p>

# %%
new_df=df.groupby(['Educational Attainment','Personal Income'],as_index=False).sum("Population Count")

# %%
new_df
# Out:
#             Educational Attainment      Personal Income  Population Count
# 0      Bachelor's degree or higher        A: 0 to 4,999            575491
# 1      Bachelor's degree or higher    B: 5,000 to 9,999            326020
# 2      Bachelor's degree or higher  C: 10,000 to 14,999            452449
# 3      Bachelor's degree or higher  D: 15,000 to 24,999            773684
# 4      Bachelor's degree or higher  E: 25,000 to 34,999            693884
# 5      Bachelor's degree or higher  F: 35,000 to 49,999           1122791
# 6      Bachelor's degree or higher  G: 50,000 to 74,999           1594681
# 7      Bachelor's degree or higher   H: 75,000 and over           2986698
# 8   College, less than 4-yr degree        A: 0 to 4,999            985011
# 9   College, less than 4-yr degree    B: 5,000 to 9,999            810641
# 10  College, less than 4-yr degree  C: 10,000 to 14,999            798596
# 11  College, less than 4-yr degree  D: 15,000 to 24,999           1345257
# ...

# %%
df_pivot=new_df.pivot(index='Personal Income',columns='Educational Attainment',values="Population Count")
df_pivot
# Out:
# Educational Attainment  Bachelor's degree or higher  \
# Personal Income
# A: 0 to 4,999                                575491
# B: 5,000 to 9,999                            326020
# C: 10,000 to 14,999                          452449
# D: 15,000 to 24,999                          773684
# E: 25,000 to 34,999                          693884
# F: 35,000 to 49,999                         1122791
# G: 50,000 to 74,999                         1594681
# H: 75,000 and over                          2986698
#
# Educational Attainment  College, less than 4-yr degree  \
# Personal Income
# A: 0 to 4,999                                   985011
# B: 5,000 to 9,999                               810641
# C: 10,000 to 14,999                             798596
# D: 15,000 to 24,999                            1345257
# E: 25,000 to 34,999                            1091642
# F: 35,000 to 49,999                            1112421
# G: 50,000 to 74,999                             883826
# ...

# %% [markdown]
# <p> <b> (4) </b> </p>

# %%
df_pivot=df_pivot.drop(columns=["High school or equivalent","College, less than 4-yr degree"])
df_pivot
# Out:
# Educational Attainment  Bachelor's degree or higher  No high school diploma
# Personal Income
# A: 0 to 4,999                                575491                 1204529
# B: 5,000 to 9,999                            326020                  597039
# C: 10,000 to 14,999                          452449                  664607
# D: 15,000 to 24,999                          773684                  875498
# E: 25,000 to 34,999                          693884                  464564
# F: 35,000 to 49,999                         1122791                  260579
# G: 50,000 to 74,999                         1594681                  132516
# H: 75,000 and over                          2986698                   58945

# %%
df_pivot.plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='Personal Income'>
