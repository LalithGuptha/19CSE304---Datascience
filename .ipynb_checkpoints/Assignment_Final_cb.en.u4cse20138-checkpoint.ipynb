# %% [markdown]
# ### Lab Assignment - 4
# ### CB.EN.U4CSE20138

# %% [markdown]
# ## A. Data Manipulation-Pandas
# ## Dataset - Birthrate data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-CDCbirths/master/births.csv')

# %%
df
# Out:
#        year  month  day gender  births
# 0      1969      1  1.0      F    4046
# 1      1969      1  1.0      M    4440
# 2      1969      1  2.0      F    4454
# 3      1969      1  2.0      M    4548
# 4      1969      1  3.0      F    4548
# ...     ...    ...  ...    ...     ...
# 15542  2008     10  NaN      M  183219
# 15543  2008     11  NaN      F  158939
# 15544  2008     11  NaN      M  165468
# 15545  2008     12  NaN      F  173215
# 15546  2008     12  NaN      M  181235
#
# [15547 rows x 5 columns]

# %% [markdown]
# ### Indexing

# %%
index = [i for i in range(1,15548)]
df1 = pd.DataFrame(df,index=index)

# %%
df1
# Out:
#          year  month  day gender    births
# 1      1969.0    1.0  1.0      M    4440.0
# 2      1969.0    1.0  2.0      F    4454.0
# 3      1969.0    1.0  2.0      M    4548.0
# 4      1969.0    1.0  3.0      F    4548.0
# 5      1969.0    1.0  3.0      M    4994.0
# ...       ...    ...  ...    ...       ...
# 15543  2008.0   11.0  NaN      F  158939.0
# 15544  2008.0   11.0  NaN      M  165468.0
# 15545  2008.0   12.0  NaN      F  173215.0
# 15546  2008.0   12.0  NaN      M  181235.0
# 15547     NaN    NaN  NaN    NaN       NaN
#
# [15547 rows x 5 columns]

# %% [markdown]
# ### Missing values

# %%
df1.columns
# Out:
# Index(['year', 'month', 'day', 'gender', 'births'], dtype='object')

# %%
for i in df1.columns:
    print(df1[i].isnull().sum())
# Out:
# 1
# 1
# 481
# 1
# 1

# %%
for i in df1.columns:
    if i!='gender':
        df1[i].fillna(np.mean(df1[i]),inplace=True)

# %%
df1.isna().sum()
# Out:
# year      0
# month     0
# day       0
# gender    1
# births    0
# dtype: int64

# %%
x = df1['gender'].mode()
df1['gender'].fillna(x[0],inplace=True)

# %%
df1.isna().sum()
# Out:
# year      0
# month     0
# day       0
# gender    0
# births    0
# dtype: int64

# %% [markdown]
# ### concat

# %%
grid = [[1,2,3],[4,5,6]]
print(len(grid[0]))
# Out:
# 3

# %%
import math
l = len(df1)
l=math.ceil(l/2)
df3 = df1[:l]
df4 = df1[l:]
df5 = pd.concat([df3,df4])
df5
# Out:
#               year      month        day gender         births
# 1      1969.000000   1.000000   1.000000      M    4440.000000
# 2      1969.000000   1.000000   2.000000      F    4454.000000
# 3      1969.000000   1.000000   2.000000      M    4548.000000
# 4      1969.000000   1.000000   3.000000      F    4548.000000
# 5      1969.000000   1.000000   3.000000      M    4994.000000
# ...            ...        ...        ...    ...            ...
# 15543  2008.000000  11.000000  17.771008      F  158939.000000
# 15544  2008.000000  11.000000  17.771008      M  165468.000000
# 15545  2008.000000  12.000000  17.771008      F  173215.000000
# 15546  2008.000000  12.000000  17.771008      M  181235.000000
# 15547  1979.038081   6.516274  17.771008      F    9762.661263
#
# [15547 rows x 5 columns]

# %% [markdown]
# ### Append

# %%
df6 = df3.append(df4)
df6
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23092\565437931.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df6 = df3.append(df4)
#               year      month        day gender         births
# 1      1969.000000   1.000000   1.000000      M    4440.000000
# 2      1969.000000   1.000000   2.000000      F    4454.000000
# 3      1969.000000   1.000000   2.000000      M    4548.000000
# 4      1969.000000   1.000000   3.000000      F    4548.000000
# 5      1969.000000   1.000000   3.000000      M    4994.000000
# ...            ...        ...        ...    ...            ...
# 15543  2008.000000  11.000000  17.771008      F  158939.000000
# 15544  2008.000000  11.000000  17.771008      M  165468.000000
# 15545  2008.000000  12.000000  17.771008      F  173215.000000
# 15546  2008.000000  12.000000  17.771008      M  181235.000000
# 15547  1979.038081   6.516274  17.771008      F    9762.661263
#
# [15547 rows x 5 columns]

# %% [markdown]
# ### merge and join

# %%
df7 = pd.merge(df3,df4,how='inner')
df7
# Out:
# Empty DataFrame
# Columns: [year, month, day, gender, births]
# Index: []

# %% [markdown]
# ### Aggregation

# %%
df1.sum()
# Out:
# year                                        30768105.038081
# month                                         101308.516274
# day                                            276285.85464
# gender    MFMFMFMFMFMFMFMFMFMFMFMFMFMFMFMFMFMFMFMFMFMFMF...
# births                                     151780094.661263
# dtype: object

# %%
df1.mean()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23092\2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# year      1979.038081
# month        6.516274
# day         17.771008
# births    9762.661263
# dtype: float64

# %%
df1.min()
# Out:
# year      1969.0
# month        1.0
# day          1.0
# gender         F
# births       1.0
# dtype: object

# %%
df1.max()
# Out:
# year        2008.0
# month         12.0
# day           99.0
# gender           M
# births    199622.0
# dtype: object

# %%
df1.median()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23092\2279417019.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.median()
# year      1979.0
# month        7.0
# day         17.0
# births    4814.0
# dtype: float64

# %%
df1.std()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23092\3039516898.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.std()
# year          6.727859
# month         3.449348
# day          15.045627
# births    28552.429000
# dtype: float64

# %%
df1.prod()
# Out:
# D:\Application\Anaconda\lib\site-packages\numpy\core\_methods.py:52: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23092\1211784430.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.prod()
# year      inf
# month     inf
# day       inf
# births    inf
# dtype: float64

# %%
df1.mad()
# Out:
# year         5.452924
# month        2.995740
# day          9.204946
# births    9853.394172
# dtype: float64

# %% [markdown]
# ### Transform

# %%
df8 = df1.groupby('year').transform(lambda x: x - x.mean())
df8
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23092\1067088748.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.transform is deprecated. In a future version, a TypeError will be raised. Before calling .transform, select only columns which should be valid for the function.
#   df8 = df1.groupby('year').transform(lambda x: x - x.mean())
#           month        day        births
# 1     -5.507171 -17.616688   -248.604954
# 2     -5.507171 -16.616688   -234.604954
# 3     -5.507171 -16.616688   -140.604954
# 4     -5.507171 -15.616688   -140.604954
# 5     -5.507171 -15.616688    305.395046
# ...         ...        ...           ...
# 15543  4.500000   0.000000 -18359.166667
# 15544  4.500000   0.000000 -11830.166667
# 15545  5.500000   0.000000  -4083.166667
# 15546  5.500000   0.000000   3936.833333
# 15547  0.000000   0.000000      0.000000
#
# [15547 rows x 3 columns]

# %%
def norm_by_data2(x):
 # x is a DataFrame of group values
 x['month'].mean()
 return x
print(df1); 
print(df1.groupby('month').apply(norm_by_data2))
df1.groupby('month').apply(norm_by_data2)
# Out:
#               year      month        day gender         births
# 1      1969.000000   1.000000   1.000000      M    4440.000000
# 2      1969.000000   1.000000   2.000000      F    4454.000000
# 3      1969.000000   1.000000   2.000000      M    4548.000000
# 4      1969.000000   1.000000   3.000000      F    4548.000000
# 5      1969.000000   1.000000   3.000000      M    4994.000000
# ...            ...        ...        ...    ...            ...
# 15543  2008.000000  11.000000  17.771008      F  158939.000000
# 15544  2008.000000  11.000000  17.771008      M  165468.000000
# 15545  2008.000000  12.000000  17.771008      F  173215.000000
# 15546  2008.000000  12.000000  17.771008      M  181235.000000
# 15547  1979.038081   6.516274  17.771008      F    9762.661263
#
# [15547 rows x 5 columns]
#               year      month        day gender         births
# 1      1969.000000   1.000000   1.000000      M    4440.000000
# 2      1969.000000   1.000000   2.000000      F    4454.000000
# 3      1969.000000   1.000000   2.000000      M    4548.000000
# 4      1969.000000   1.000000   3.000000      F    4548.000000
# 5      1969.000000   1.000000   3.000000      M    4994.000000
# ...            ...        ...        ...    ...            ...
# 15543  2008.000000  11.000000  17.771008      F  158939.000000
# 15544  2008.000000  11.000000  17.771008      M  165468.000000
# 15545  2008.000000  12.000000  17.771008      F  173215.000000
# 15546  2008.000000  12.000000  17.771008      M  181235.000000
# 15547  1979.038081   6.516274  17.771008      F    9762.661263
#
# [15547 rows x 5 columns]
#               year      month        day gender         births
# 1      1969.000000   1.000000   1.000000      M    4440.000000
# 2      1969.000000   1.000000   2.000000      F    4454.000000
# 3      1969.000000   1.000000   2.000000      M    4548.000000
# 4      1969.000000   1.000000   3.000000      F    4548.000000
# 5      1969.000000   1.000000   3.000000      M    4994.000000
# ...            ...        ...        ...    ...            ...
# 15543  2008.000000  11.000000  17.771008      F  158939.000000
# 15544  2008.000000  11.000000  17.771008      M  165468.000000
# 15545  2008.000000  12.000000  17.771008      F  173215.000000
# 15546  2008.000000  12.000000  17.771008      M  181235.000000
# 15547  1979.038081   6.516274  17.771008      F    9762.661263
#
# [15547 rows x 5 columns]

# %% [markdown]
# ### Pivot table

# %%
df1.pivot_table(index='gender')
# Out:
#               births        day     month         year
# gender
# F        9521.802940  17.784698  6.514084  1979.038714
# M       10003.674559  17.757308  6.518466  1979.037447

# %% [markdown]
# ## B. Time Series

# %%
ts = pd.read_csv('Fremont_Bridge_Bicycle_Counter.csv',index_col='Date',parse_dates=True)

# %%
ts
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
# ...                                   ...                           ...
# 2022-09-30 19:00:00                 168.0                          57.0
# 2022-09-30 20:00:00                  73.0                          33.0
# 2022-09-30 21:00:00                  69.0                          30.0
# 2022-09-30 22:00:00                  51.0                          10.0
# 2022-09-30 23:00:00                  59.0                          22.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0
# ...                                           ...
# 2022-09-30 19:00:00                         111.0
# 2022-09-30 20:00:00                          40.0
# 2022-09-30 21:00:00                          39.0
# 2022-09-30 22:00:00                          41.0
# 2022-09-30 23:00:00                          37.0
#
# [87600 rows x 3 columns]

# %%
ts.columns = ['Total','West', 'East']

# %%
ts
# Out:
#                      Total  West   East
# Date
# 2012-10-03 00:00:00   13.0   4.0    9.0
# 2012-10-03 01:00:00   10.0   4.0    6.0
# 2012-10-03 02:00:00    2.0   1.0    1.0
# 2012-10-03 03:00:00    5.0   2.0    3.0
# 2012-10-03 04:00:00    7.0   6.0    1.0
# ...                    ...   ...    ...
# 2022-09-30 19:00:00  168.0  57.0  111.0
# 2022-09-30 20:00:00   73.0  33.0   40.0
# 2022-09-30 21:00:00   69.0  30.0   39.0
# 2022-09-30 22:00:00   51.0  10.0   41.0
# 2022-09-30 23:00:00   59.0  22.0   37.0
#
# [87600 rows x 3 columns]

# %%
ts.dropna().describe()
# Out:
#               Total          West          East
# count  87586.000000  87586.000000  87586.000000
# mean     107.240849     48.086623     59.154226
# std      134.790561     61.573965     83.567491
# min        0.000000      0.000000      0.000000
# 25%       13.000000      6.000000      7.000000
# 50%       60.000000     27.000000     30.000000
# 75%      144.000000     66.000000     75.000000
# max     1097.000000    698.000000    850.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={"figure.figsize":(20, 10)})
#plt.figure(figsize=(20,20))
ts.plot()
plt.ylabel('Hourly Bicycle Count')
# Out:
# Text(0, 0.5, 'Hourly Bicycle Count')

# %%
weekly = ts.resample('W').sum()
weekly.plot(style=[':', '--', '-'])
plt.ylabel('Weekly bicycle count');

# %%
daily = ts.resample('D').sum()
daily.rolling(30, center=True).sum().plot(style=[':', '--', '-'])
plt.ylabel('mean hourly count')
# Out:
# Text(0, 0.5, 'mean hourly count')

# %%
daily.rolling(50, center=True,win_type='gaussian').sum(std=10).plot(style=[':', '--', '-'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
by_time = ts.groupby(ts.index.time).mean()
hourly_ticks = 4 * 60 * 60 * np.arange(6)
by_time.plot(xticks=hourly_ticks, style=[':', '--', '-'])
# Out:
# <AxesSubplot:xlabel='time'>

# %%
by_weekday = ts.groupby(ts.index.dayofweek).mean()
by_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(style=[':', '--', '-']);

# %%
weekend = np.where(ts.index.weekday < 5, 'Weekday', 'Weekend')
by_time = ts.groupby([weekend, ts.index.time]).mean()
# weekday = np.where(ts.index.weekday >= 5, 'Weekday', 'Weekend')
# by_time = ts.groupby([weekday, ts.index.time]).mean()

# %% [markdown]
# ### C. Classifier

# %% [markdown]
# ### Q5

# %%
x = pd.read_csv('wine.csv')

# %%
x
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# 2                    0.30     2.81       5.68  1.03  3.17     1185
# 3                    0.24     2.18       7.80  0.86  3.45     1480
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ..                    ...      ...        ...   ...   ...      ...
# 173                  0.52     1.06       7.70  0.64  1.74      740
# 174                  0.43     1.41       7.30  0.70  1.56      750
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 176                  0.53     1.46       9.30  0.60  1.62      840
# 177                  0.56     1.35       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %%
x.isna().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split
X = x.drop(['Wine'],axis='columns')
y = x['Wine']
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=50)

# %%
error1= []
error2= []
for k in range(1,10):
    knn= KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    y_pred1= knn.predict(X_train)
    error1.append(np.mean(y_train!= y_pred1))
    y_pred2= knn.predict(X_test)
    error2.append(np.mean(y_test!= y_pred2))

plt.plot(range(1,10),error1,label="train")
plt.plot(range(1,10),error2,label="test")
plt.xlabel('k Value')
plt.ylabel('Error')
plt.legend()

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
knn.score(X_test, y_test)
# Out:
# 0.75

# %%
from sklearn.metrics import confusion_matrix
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[10,  1,  2],
#        [ 1, 13,  0],
#        [ 1,  4,  4]], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(7,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(39.5, 0.5, 'Truth')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.83      0.77      0.80        13
#            2       0.72      0.93      0.81        14
#            3       0.67      0.44      0.53         9
#
#     accuracy                           0.75        36
#    macro avg       0.74      0.71      0.72        36
# weighted avg       0.75      0.75      0.74        36

# %%
#other classifier

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(random_state =1, max_features=4)

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=50)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_features=4, random_state=1)

# %%
y_pred = rf.predict(X_test)

# %%
rf.score(X_test, y_test)
# Out:
# 0.9208835051546392

# %%
from sklearn.metrics import confusion_matrix
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[10,  1,  2],
#        [ 1, 13,  0],
#        [ 1,  4,  4]], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(7,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(39.5, 0.5, 'Truth')

# %%
#other classifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from sklearn.svm import SVC
svm = SVC(C=10000,gamma=0.00001)
svm.fit(X_train,y_train)
# Out:
# SVC(C=10000, gamma=1e-05)

# %%
svm.score(X_test, y_test)
# Out:
# 0.9661016949152542
